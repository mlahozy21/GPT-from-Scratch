# %% [markdown]
# # Training a GPT from scratch
#
# A modern decoder-only Transformer (RoPE, RMSNorm, SwiGLU, KV-cache) implemented
# from scratch in PyTorch and trained on TinyStories. **Runtime → GPU.**

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/mlahozy21/GPT-from-Scratch.git
# %cd GPT-from-Scratch
# !pip install -q -e .

# %% [markdown]
# ### Sanity check the implementation (synthetic copy task, ~30 s)

# %%
# !python scripts/smoke_test.py

# %% [markdown]
# ### Prepare data (TinyStories, BPE)

# %%
# !python scripts/prepare_data.py --max-docs 200000

# %% [markdown]
# ### Train (adjust size/iters to your compute budget)

# %%
# !python scripts/train.py --n-layer 8 --n-head 8 --n-embd 512 --max-iters 5000

# %% [markdown]
# ### Generate

# %%
# !python scripts/generate.py --prompt "Once upon a time" --max-new-tokens 200

# %% [markdown]
# ### (Optional) Scaling study

# %%
# !python scripts/scaling_study.py --max-iters 3000
